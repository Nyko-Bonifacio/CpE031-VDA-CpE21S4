# %% [markdown]
# <a href="https://colab.research.google.com/github/Nyko-Bonifacio/CpE031-VDA-CpE21S4/blob/main/Exercise_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([0,6])
ypoints=np.array([0,250])

plt.plot(xpoints,ypoints,'o')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints,marker ='*')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,'*:r')
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,'*:r', ms=100)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(ypoints,'*:r', ms=50, mec = 'violet', mfc = 'green', linestyle = 'dashed',  linewidth=3)
plt.plot(xpoints,'*:b', ms=50, mec = 'yellow', mfc = 'orange', linestyle = 'dashdot', linewidth=5)
plt.show()
# Out:
# <ipython-input-70-a0aa128acd44>:4: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "*:r" (-> linestyle=':'). The keyword argument will take precedence.
#   plt.plot(ypoints,'*:r', ms=50, mec = 'violet', mfc = 'green', linestyle = 'dashed',  linewidth=3)
# <ipython-input-70-a0aa128acd44>:5: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "*:b" (-> linestyle=':'). The keyword argument will take precedence.
#   plt.plot(xpoints,'*:b', ms=50, mec = 'yellow', mfc = 'orange', linestyle = 'dashdot', linewidth=5)

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid()
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.plot(xpoints, ypoints)
plt.title("Distance Travelled Everyday")
plt.xlabel("Distance in km")
plt.ylabel("Speed in km/s")
plt.grid(axis='x', linestyle='--', linewidth=0.50)
plt.show()

# %%
#plot 1
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(xpoints, ypoints)

#plot 2
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(xpoints, ypoints)

plt.grid(axis='x', linestyle='--', linewidth=0.50)
plt.show()

# %%
xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([3, 8, 1, 10])

plt.scatter(xpoints, ypoints)

xpoints = np.array([1, 2, 6, 8])
ypoints = np.array([10, 20, 30, 40])

plt.scatter(xpoints, ypoints)

plt.show()

# %%
x = np.array(['Student 1', 'Student 2', 'Student 3'])
y = np.array([90, 85, 96])
plt.ylabel("Students Grades")
plt.bar(x, y, color="red")
plt.show()

# %%
g = np.array([35, 25, 25, 15])
grader = ["Grade 1 = 35%", "Grade 2 = 25%", "Grade 3 = 25%", "Grade 4 = 15%"]
plt.pie(g,labels = grader)
plt.show()

# %% [markdown]
# # Laboratory: Introduction to Matplot
#
# ---

# %% [markdown]
# # **1**

# %% [markdown]
# Line Pot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [ 10, 20, 30, 40]

plt.plot(x, y)
plt.title("Line Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# Scatter Plot

# %%
import matplotlib.pyplot as plt

x = [1, 2, 3, 4]
y = [ 10, 20, 30, 40]

plt.scatter(x, y)
plt.title("Scatter Plot Example")
plt.xlabel("X-axis")
plt.ylabel("Y-axis")
plt.show()

# %% [markdown]
# Histogram

# %%
import matplotlib.pyplot as plt

data = [1, 2, 2, 3, 3, 3, 4]

plt.hist(data)
plt.title("Histogram Example")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()

# %% [markdown]
# Bar Chart

# %%
import matplotlib.pyplot as plt

categories = ['A', 'B', 'C']
values = [5, 7, 3]

plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Categories")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# Box Plot

# %%
import matplotlib.pyplot as plt

data = [[1.5]*10 + [2]*10 + [3]*10]

plt.boxplot(data)

plt.title("Box Plot Example")
plt.ylabel("Values")
plt.show()

# %% [markdown]
# Pie Chart

# %%
import matplotlib.pyplot as plt

labels = ['A', 'B', 'C']
sizes = [40, 30, 30]

plt.pie(sizes, labels=labels)
plt.title("Pie Chart Example")
plt.show()

# %% [markdown]
# # **2**

# %%
import pandas as pd

file_path = '/content/ComputerData.csv'
df = pd.read_csv('/content/ComputerData.csv')

df.head()
# Out:
#    Computer ID   Brand        Model    Processor  RAM (GB)  Storage (GB)  \
# 0            1    Dell       XPS 13     Intel i7        16           512
# 1            2      HP  Pavilion 15  AMD Ryzen 5         8           256
# 2            3   Apple  MacBook Pro     Apple M1        16          1024
# 3            4  Lenovo  ThinkPad X1     Intel i9        32           512
# 4            5    Asus   ZenBook 14     Intel i5        16           512
#
#       Graphics Card  Price ($)
# 0     Intel Iris Xe       1200
# 1        AMD Radeon        800
# 2  Apple Integrated       2400
# 3   NVIDIA GTX 1650       1800
# 4      NVIDIA MX250       1000

# %%
import matplotlib.pyplot

# %% [markdown]
# **Three Questions**
#
# 1.  What are the ram sizes per Model?
# 2.  What are the different Storage size per Model?
# 3.  What is the average price of Computers by Brand?

# %% [markdown]
# 1

# %%
#1
data = pd.read_csv('ComputerData.csv')


x = data['Model']
y = data['RAM (GB)']

plt.scatter(x, y)
plt.xlabel("Model")
plt.ylabel("Ram Size")
plt.show()

# %% [markdown]
# 2

# %%
#2
data = pd.read_csv('ComputerData.csv')

categories = data['Model']
values = data['Storage (GB)']

plt.figure(figsize=(12, 6))
plt.bar(categories, values)
plt.title("Bar Chart Example")
plt.xlabel("Brands / Models")
plt.ylabel("Storage Size")
plt.show()

# %%
#3
data = pd.read_csv('ComputerData.csv')

categories = data['Brand']
values = data['Price ($)']

plt.bar(categories, values)
plt.title("Average Price of Computers by Brand")
plt.xlabel("Brand")
plt.ylabel("Average Price ($)")
plt.xticks(rotation=45)
plt.show()
